# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
graph = pd.Series(np.random.randn(1000), index = pd.date_range("1/1/2020", periods=1000))
graph = graph.cumsum()
graph.plot()
# Out:
# <AxesSubplot:>
